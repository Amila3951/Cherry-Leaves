# %% [markdown]
# ## Data Collecion

# %% [markdown]
# ## Objectives
#
# * Fetch the cherry leaves dataset from Kaggle.
# * Verify the integrity of the downloaded data.

# %% [markdown]
# ## Inputs
#
# * URL of the Kaggle dataset: https://www.kaggle.com/codeinstitute/cherry-leaves
# * Kaggle.json file -authentication token

# %% [markdown]
# ## Outputs
#
# * `data/cherry-leaves.zip`

# %%
## Change the working directory

import os

# Print the current working directory
print("Current working directory:", os.getcwd())

# Change the working directory to the correct path
os.chdir('/workspace/Cherry-Leaves')

# Verify the change
print("New working directory:", os.getcwd())
# Out:
# Current working directory: /workspaces/Cherry-Leaves/jupyter_notebooks
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       6 print("Current working directory:", os.getcwd())
#       8 # Change the working directory to the correct path
# ----> 9 os.chdir('/workspace/Cherry-Leaves')
#      11 # Verify the change
#      12 print("New working directory:", os.getcwd())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/Cherry-Leaves'

# %%
# Install Kaggle library

# %pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Set up Kaggle API credentials

import os
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()

# %%
# Download the dataset

# Set Kaggle Dataset path
KaggleDatasetPath = "codeinstitute/cherry-leaves"

# Set the destination folder for the downloaded dataset
DestinationFolder = "data"

# Download the dataset
# !kaggle datasets download -d {KaggleDatasetPath} -p {DestinationFolder}
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/codeinstitute/cherry-leaves
# License(s): unknown
# cherry-leaves.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Unzip the downloaded file

import zipfile

# Unzip the downloaded dataset
with zipfile.ZipFile(DestinationFolder + '/cherry-leaves.zip', 'r') as zip_ref:
    zip_ref.extractall(DestinationFolder)
