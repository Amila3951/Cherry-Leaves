# %% [markdown]
# # Modelling and Evaluating Cherry Leaf Images

# %% [markdown]
# ## Objectives
# * Build a CNN model to classify cherry leaf images as healthy or powdery_mildew.
# * Train the model using the preprocessed data with augmentation.
# * Evaluate the model's performance on unseen test data.

# %%
## Inputs

outputs = 'outputs'

'outputs/v1/image_shape.pkl'
'data/cherry-leaves/train'
'data/cherry-leaves/test'
'data/cherry-leaves/validation'
# Out:
# 'data/cherry-leaves/validation'

# %% [markdown]
# ## Outputs
# * Trained CNN model (outputs/v1/cherry_leaves_model.h5).
# * Model evaluation metrics (accuracy, loss, etc.).
# * Learning curve plot (outputs/v1/model_training_losses.png and outputs/v1/model_training_acc.png).
# * Model evaluation on pickle file (outputs/v1/evaluation.pkl).
# * Prediction on a random image file.

# %%
## 1. Import Libraries

import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import seaborn as sns
import joblib  
import math

# %%
## 2. Load Image Shape
image_shape = joblib.load('../outputs/v1/image_shape.pkl')

# %%
## 3. Data Preprocessing and Augmentation
# Define data generators with augmentation (adjust parameters as needed)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    '/workspaces/Cherry-Leaves/data/cherry-leaves/train',
    target_size=image_shape[:2],
    batch_size=32,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    '/workspaces/Cherry-Leaves/data/cherry-leaves/validation',
    target_size=image_shape[:2],
    batch_size=32,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    '/workspaces/Cherry-Leaves/data/cherry-leaves/test',
    target_size=image_shape[:2],
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 4105 images belonging to 2 classes.
# Found 1623 images belonging to 2 classes.
# Found 1640 images belonging to 2 classes.

# %%
## 4. Model Building
def create_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=image_shape))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))  # Adding dropout for regularization
    model.add(Dense(1, activation='sigmoid'))
    return model

model = create_model()
model.summary()
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
## 5. Compile the Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
## 6. Train the Model

import math
from tensorflow.keras.callbacks import EarlyStopping


batch_size = 16  # You can adjust this as needed

# Calculate steps per epoch
steps_per_epoch = math.ceil(train_generator.samples / batch_size)

# Initialize EarlyStopping 
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Compile the model 
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) # Or your chosen loss, optimizer, and metrics

# Fit the model with EarlyStopping callback
history = model.fit(
    train_generator,
    epochs=10,  # Increased max epochs (training will stop earlier if needed)
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# /home/codespace/.local/lib/python3.12/site-packages/keras/src/losses/losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 129/257 ━━━━━━━━━━━━━━━━━━━━ 2:35 1s/step - accuracy: 0.5043 - loss: 0.0000e+00
# ...

# %%
## 7. Evaluate the Model
loss, accuracy = model.evaluate(test_generator)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 15s 293ms/step - accuracy: 0.5081 - loss: 0.0000e+00
# Test Loss: 0.0
# Test Accuracy: 0.5012195110321045
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os

# Define the exact path where you want to save the model
model_path = '/workspaces/Cherry-Leaves/outputs/v2/cherry_leaves_model.keras'

# Extract the directory path from the full model path
directory = os.path.dirname(model_path)

# Check if the directory exists. If it doesn't, create it.
if not os.path.exists(directory):
    os.makedirs(directory)

# Save the model to the specified path
model.save(model_path)

# Print a confirmation message indicating the save location
print(f"Model saved successfully at: {model_path}")

# %%
## 9. Model Performance
### 9.1 Model Learning Curve

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

output_dir = "/workspaces/Cherry-Leaves/outputs/v2"

# Check if the history object exists and is not empty
if hasattr(model, 'history') and model.history is not None and hasattr(model.history, 'history') and model.history.history:
    history = model.history.history  # Store the history for easier access

    sns.set_style("whitegrid")

    # Function to plot and save a metric 
    def plot_metric(metric, title, filename):
        if metric in history:
            plt.figure(figsize=(10, 6))  # Adjust figure size for better visualization
            plt.plot(history[metric], label=metric, linewidth=2)  # Increase linewidth
            if f'val_{metric}' in history:
                plt.plot(history[f'val_{metric}'], label=f'val_{metric}', linewidth=2, linestyle='--') # Add validation
            plt.title(title, fontsize=16)  # Increase title font size
            plt.xlabel("Epoch", fontsize=14)  # Increase axis label font size
            plt.ylabel(metric.capitalize(), fontsize=14)  # Capitalize y-axis label
            plt.legend(fontsize=12) # Increase legend font size
            plt.xticks(fontsize=12) # Increase tick font size
            plt.yticks(fontsize=12) # Increase tick font size
            plt.grid(True, alpha=0.5) # Add a slightly transparent grid
            plt.tight_layout() # Adjust layout to prevent labels from overlapping
            plt.savefig(os.path.join(output_dir, filename), bbox_inches='tight', dpi=150)
            plt.show()
        else:
            print(f"{metric} not found in training history.")

    plot_metric('loss', "Loss", "model_training_losses.png")
    plot_metric('accuracy', "Accuracy", "model_training_acc.png")

else:
    print("Model training history is not available. Make sure model.fit() has been run successfully.")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import joblib

# --- Define image dimensions and batch size ---
img_width, img_height = 224, 224  
batch_size = 32 

output_dir = "/workspaces/Cherry-Leaves/outputs/v2"

# --- Load saved model ---
model = load_model('/workspaces/Cherry-Leaves/outputs/v2/cherry_leaves_model.keras')

# --- Define the path to test data directory ---
test_data_dir = '/workspaces/Cherry-Leaves/data/cherry-leaves/test'

# --- Create an ImageDataGenerator with any necessary preprocessing steps ---
test_datagen = ImageDataGenerator(rescale=1./255)

# --- Create a test generator ---
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(256, 256),
    batch_size=batch_size,
    class_mode='binary'
)

# --- Evaluate model accuracy on the test set ---
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# --- Save evaluation results ---
evaluation = model.evaluate(test_generator, verbose=1)
joblib.dump(value=evaluation, filename=f"{output_dir}/evaluation.pkl")
# Out:
# Found 1640 images belonging to 2 classes.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 12s 220ms/step - accuracy: 0.9984 - loss: 0.0035
# Test Accuracy: 99.82%
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 11s 220ms/step - accuracy: 0.9990 - loss: 0.0026
# ['/workspaces/Cherry-Leaves/outputs/v2/evaluation.pkl']

# %%
import os
import random

from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# --- Define paths and parameters ---
test_path = '/workspaces/Cherry-Leaves/data/cherry-leaves/test'
train_data_dir = '/workspaces/Cherry-Leaves/data/cherry-leaves/train'
img_width, img_height = 256, 256

# --- Load saved model ---
model = load_model('/workspaces/Cherry-Leaves/outputs/v2/cherry_leaves_model.keras')

# --- Predict on new data ---

# Define labels
labels = ['healthy', 'powdery_mildew']

# Load a random image
label = random.choice(labels)
pointer = random.randint(0, len(os.listdir(test_path + '/' + label)) - 1)
image_path = test_path + '/' + label + '/' + os.listdir(test_path + '/' + label)[pointer]
pil_image = image.load_img(image_path, target_size=(img_width, img_height), color_mode='rgb')
print(f'Image path: {image_path}, Image shape: {pil_image.size}, Image mode: {pil_image.mode}')

# Convert image to array and prepare for prediction
my_image = image.img_to_array(pil_image)
my_image = np.expand_dims(my_image, axis=0) / 255
print(my_image.shape)

# Predict class probabilities
pred_proba = model.predict(my_image)

# Create a training generator to get class indices
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='binary'
)

target_map = {v: k for k, v in train_generator.class_indices.items()}


predicted_class_index = int(round(pred_proba[0][0]))  
pred_class = target_map[predicted_class_index]
predicted_probability = pred_proba[0][0]

print(f"Predicted probability: {predicted_probability:.4f}")
print(f"Predicted class: {pred_class}")
# Out:
# Image path: /workspaces/Cherry-Leaves/data/cherry-leaves/test/powdery_mildew/fffc6a5c-66f3-4d73-afd2-84862fb83c4f___FREC_Pwd.M 5085.JPG, Image shape: (256, 256), Image mode: RGB
# (1, 256, 256, 3)
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7453e7e8b740> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# ...
